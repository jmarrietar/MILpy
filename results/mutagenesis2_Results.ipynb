# %% [markdown]
# # Results: mutagenesis2 Original

# %% [markdown]
# <b> MIL </b>  <i>stratified k fold Validation</i>  is performed.
# Metrics: <br>
#     - AUC
#     - Accuracie

# %% [markdown]
# ### Import Libraries

# %%
import sys,os
import warnings
os.chdir('/Users/josemiguelarrieta/Documents/MILpy')
sys.path.append(os.path.realpath('..'))
from sklearn.utils import shuffle
import random as rand
import numpy as np
from data import load_data
warnings.filterwarnings('ignore')
from MILpy.functions.mil_cross_val import mil_cross_val

#Import Algorithms 
from MILpy.Algorithms.simpleMIL import simpleMIL
from MILpy.Algorithms.MILBoost import MILBoost
from MILpy.Algorithms.maxDD import maxDD
from MILpy.Algorithms.CKNN import CKNN
from MILpy.Algorithms.EMDD import EMDD
from MILpy.Algorithms.MILES import MILES
from MILpy.Algorithms.BOW import BOW

# %% [markdown]
# ### Load data

# %%
bags,labels,X = load_data('mutagenesis2_original')
folds = 5
runs = 5

# %% [markdown]
# #### Simple MIL [max]

# %%
SMILa = simpleMIL()
parameters_smil = {'type': 'max'}
print '\n========= SIMPLE MIL RESULT [MAX] ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    #Shuffle Data
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed  = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=folds, parameters=parameters_smil, timer = True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= SIMPLE MIL RESULT [MAX] =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 65.0
# Accuracie: 78.4523809524
# Elapsed: 0.01
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 68.3333333333
# Accuracie: 81.0317460317
# Elapsed: 0.01
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 63.3333333333
# Accuracie: 78.1746031746
# Elapsed: 0.02
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 65.0
# Accuracie: 78.4523809524
# Elapsed: 0.01
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 63.3333333333
# Accuracie: 78.1746031746
# Elapsed: 0.01
#
#  MEAN AUC: 65.0
#  MEAN ACCURACIE: 78.8571428571

# %% [markdown]
# #### Simple MIL [min]

# %%
parameters_smil = {'type': 'min'}
print '\n========= SIMPLE MIL RESULT [MIN] ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed   = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=folds,parameters=parameters_smil, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= SIMPLE MIL RESULT [MIN] =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 0.01
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 48.3333333333
# Accuracie: 64.8412698413
# Elapsed: 0.01
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 46.6666666667
# Accuracie: 64.2857142857
# Elapsed: 0.02
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 0.01
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 0.01
#
#  MEAN AUC: 49.0
#  MEAN ACCURACIE: 67.3968253968

# %% [markdown]
# #### Simple MIL [extreme]

# %%
parameters_smil = {'type': 'extreme'}
print '\n========= SIMPLE MIL RESULT [MIN] ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    #Shuffle Data
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=folds,parameters=parameters_smil, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= SIMPLE MIL RESULT [MIN] =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 68.3333333333
# Accuracie: 81.0317460317
# Elapsed: 0.01
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 70.0
# Accuracie: 81.6666666667
# Elapsed: 0.01
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 70.0
# Accuracie: 81.3095238095
# Elapsed: 0.02
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 70.0
# Accuracie: 81.3095238095
# Elapsed: 0.01
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 60.0
# Accuracie: 75.9523809524
# Elapsed: 0.01
#
#  MEAN AUC: 67.6666666667
#  MEAN ACCURACIE: 80.253968254

# %% [markdown]
# #### Simple MIL [average]

# %%
parameters_smil = {'type': 'average'}
print '\n========= SIMPLE MIL RESULT [AVERAGE] ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed   = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=folds,parameters=parameters_smil, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= SIMPLE MIL RESULT [AVERAGE] =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 71.6666666667
# Accuracie: 81.5873015873
# Elapsed: 0.02
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 65.0
# Accuracie: 78.4523809524
# Elapsed: 0.02
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 65.0
# Accuracie: 78.8095238095
# Elapsed: 0.02
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 58.3333333333
# Accuracie: 74.0079365079
# Elapsed: 0.01
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 70.0
# Accuracie: 81.3095238095
# Elapsed: 0.01
#
#  MEAN AUC: 66.0
#  MEAN ACCURACIE: 78.8333333333

# %% [markdown]
# #### Bag of Words

# %%
bow_classifier = BOW() 
parameters_bow = {'k':100,'covar_type':'diag','n_iter':20}
print '\n========= BAG OF WORDS RESULT ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed = mil_cross_val(bags=bags,labels=labels.ravel(), model=bow_classifier, folds=folds,parameters=parameters_bow, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= BAG OF WORDS RESULT =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 71.6666666667
# Accuracie: 81.9444444444
# Elapsed: 11.9
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 63.3333333333
# Accuracie: 76.8650793651
# Elapsed: 10.42
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 68.3333333333
# Accuracie: 79.7222222222
# Elapsed: 10.55
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 66.6666666667
# Accuracie: 79.0873015873
# Elapsed: 12.93
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 71.6666666667
# Accuracie: 81.9444444444
# Elapsed: 15.7
#
#  MEAN AUC: 68.3333333333
#  MEAN ACCURACIE: 79.9126984127

# %% [markdown]
# #### Citation KNN

# %%
cknn_classifier = CKNN() 
parameters_cknn = {'references': 3, 'citers': 5}
print '\n========= CKNN RESULT ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed   = mil_cross_val(bags=bags,labels=labels.ravel(), model=cknn_classifier, folds=folds,parameters=parameters_cknn, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= CKNN RESULT =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 71.6666666667
# Accuracie: 80.6746031746
# Elapsed: 2560.21
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 74.3333333333
# Accuracie: 77.8174603175
# Elapsed: 1564.04
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 74.3333333333
# Accuracie: 80.3968253968
# Elapsed: 6552.59
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 71.0
# Accuracie: 77.8174603175
# Elapsed: 3282.71
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 69.0
# Accuracie: 75.0396825397
# Elapsed: 2975.09
#
#  MEAN AUC: 72.0666666667
#  MEAN ACCURACIE: 78.3492063492

# %% [markdown]
# #### Diverse Density

# %%
maxDD_classifier = maxDD()
print '\n========= DIVERSE DENSITY RESULT========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed = mil_cross_val(bags=bags,labels=labels.ravel(), model=maxDD_classifier, folds=folds,parameters={}, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= DIVERSE DENSITY RESULT=========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 19.61
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 65.0
# Accuracie: 78.4523809524
# Elapsed: 17.72
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 25.18
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 19.91
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 50.0
# Accuracie: 69.2857142857
# Elapsed: 44.51
#
#  MEAN AUC: 53.0
#  MEAN ACCURACIE: 71.119047619

# %% [markdown]
# #### EM-DD

# %%
emdd_classifier = EMDD()
print '\n========= EM-DD RESULT ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed = mil_cross_val(bags=bags,labels=labels.ravel(), model=emdd_classifier, folds=folds,parameters={}, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= EM-DD RESULT =========
#
#  run #0
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 56.6666666667
# Accuracie: 73.7301587302
# Elapsed: 205.8
#
#  run #1
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 61.6666666667
# Accuracie: 76.2301587302
# Elapsed: 202.82
#
#  run #2
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 56.6666666667
# Accuracie: 73.7301587302
# Elapsed: 200.5
#
#  run #3
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 61.6666666667
# Accuracie: 76.5873015873
# Elapsed: 150.41
#
#  run #4
# Fold# 0...Fold# 1...Fold# 2...Fold# 3...Fold# 4...
# AUC: 65.0
# Accuracie: 78.4523809524
# Elapsed: 131.74
#
#  MEAN AUC: 60.3333333333
#  MEAN ACCURACIE: 75.746031746

# %% [markdown]
# #### MILBoost

# %%
milboost_classifier = MILBoost()
print '\n========= MILBOOST RESULT ========='
AUC = []
ACCURACIE=[]
for i in range(runs):
    print '\n run #'+ str(i)
    bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
    accuracie, results_accuracie, auc,results_auc, elapsed = mil_cross_val(bags=bags,labels=labels, model=milboost_classifier, folds=folds,parameters={}, timer=True)
    print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
    AUC.append(auc)
    ACCURACIE.append(accuracie)
print '\n MEAN AUC: '+ str(np.mean(AUC)) + '\n MEAN ACCURACIE: '+ str(np.mean(ACCURACIE))
# Out:
# ========= MILBOOST RESULT =========
#
#  run #0
# Fold# 0...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-04dd369fb52f> in <module>()
#       6     print '\n run #'+ str(i)
#       7     bags,labels = shuffle(bags, labels, random_state=rand.randint(0, 100))
# ----> 8     accuracie, results_accuracie, auc,results_auc, elapsed = mil_cross_val(bags=bags,labels=labels, model=milboost_classifier, folds=folds,parameters={}, timer=True)
#       9     print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)+'\n'+'Elapsed: '+ str(round(elapsed,2))
#      10     AUC.append(auc)
#
# /Users/josemiguelarrieta/Documents/MILpy/functions/mil_cross_val.pyc in mil_cross_val(bags, labels, model, folds, parameters, timer)
#      30         else:
#      31             model.fit(bags, labels)
# ---> 32         predictions = model.predict(X_test)
#      33         if (isinstance(predictions, tuple)):
#      34             predictions = predictions[0]
#
# /Users/josemiguelarrieta/Documents/MILpy/Algorithms/MILBoost.pyc in predict(self, test_bags)
#      96         out = np.zeros((n,1))
#      97         for i in range(0,T-1):
# ---> 98              out = out + float(self._alpha[i])*H[i]['bestsgn']*np.sign(Z[:,H[i]['bestfeat']]-H[i]['bestthr'])
#      99              pij = 1/(1+np.exp(-out))
#     100
#
# IndexError: list index out of range

# %% [markdown]
# #### Miles

# %%
#Pending
