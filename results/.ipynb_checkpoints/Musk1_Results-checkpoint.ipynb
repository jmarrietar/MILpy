# %% [markdown]
# # Results: Musk1 Scaled

# %% [markdown]
# <b> MIL </b>  <i>stratified k fold Validation</i>  is performed.
# Metrics: <br>
#     - AUC
#     - Accuracie
#
# k = 10 folds

# %% [markdown]
# ### Import Libraries

# %%
import sys,os
os.chdir('/Users/josemiguelarrieta/Documents/MILpy')
sys.path.append(os.path.realpath('..'))
from data import load_data
import warnings
warnings.filterwarnings('ignore')
from MILpy.functions.mil_cross_val import mil_cross_val

#Import Algorithms 
from MILpy.Algorithms.simpleMIL import simpleMIL
from MILpy.Algorithms.MILBoost import MILBoost
from MILpy.Algorithms.maxDD import maxDD
from MILpy.Algorithms.CKNN import CKNN
from MILpy.Algorithms.EMDD import EMDD
from MILpy.Algorithms.MILES import MILES
from MILpy.Algorithms.BOW import BOW

# %% [markdown]
# ### Load data

# %%
bags,labels,X = load_data('musk1_scaled')

# %% [markdown]
# #### Simple MIL [max]

# %%
SMILa = simpleMIL()

# %%
parameters_smil = {'type': 'max'}
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=10,parameters=parameters_smil)
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 75.25
# Accuracie: 75.2777777778

# %% [markdown]
# #### Simple MIL [min]

# %%
parameters_smil = {'type': 'min'}
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=10,parameters=parameters_smil)
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 84.0
# Accuracie: 84.0

# %% [markdown]
# #### Simple MIL [extreme]

# %%
parameters_smil = {'type': 'extreme'}
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=10,parameters=parameters_smil)
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 85.5
# Accuracie: 85.5

# %% [markdown]
# #### Simple MIL [average]

# %%
parameters_smil = {'type': 'average'} 
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=SMILa, folds=10,parameters=parameters_smil)
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 80.25
# Accuracie: 80.5277777778

# %% [markdown]
# #### Bag of Words

# %%
bow_classifier = BOW() 
parameters_bow = {'k':100,'covar_type':'diag','n_iter':20}
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=bow_classifier, folds=10,parameters=parameters_bow)
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 76.25
# Accuracie: 76.4444444444

# %% [markdown]
# #### Citation KNN

# %%
cknn_classifier = CKNN() 
parameters_cknn = {'references': 3, 'citers': 5}
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=cknn_classifier, folds=10,parameters=parameters_cknn)
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 86.25
# Accuracie: 86.1388888889

# %% [markdown]
# #### Diverse Density

# %%
maxDD_classifier = maxDD()
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=maxDD_classifier, folds=10,parameters={})
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 79.75
# Accuracie: 80.0277777778

# %% [markdown]
# #### EM-DD

# %%
emdd_classifier = EMDD()
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels.ravel(), model=emdd_classifier, folds=10,parameters={})
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Run# 1...Run# 2...Run# 3...Run# 4...Run# 5...Run# 6...Run# 7...Run# 8...Run# 9...
# AUC: 89.75
# Accuracie: 89.8888888889

# %% [markdown]
# #### MILBoost

# %%
milboost_classifier = MILBoost() 
accuracie, results_accuracie, auc,results_auc  = mil_cross_val(bags=bags,labels=labels, model=milboost_classifier, folds=10,parameters={})
print '\n'+'AUC: ' + str(auc)+'\n'+'Accuracie: '+ str(accuracie)
# Out:
# Run# 0...Optimization terminated successfully.
#          Current function value: 77.442259
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.437442
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.432776
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.428224
#          Iterations: 7
#          Function evaluations: 33
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 77.423811
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.419502
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.415322
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.411239
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.407274
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.403400
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.399635
#          Iterations: 6
#          Function evaluations: 53
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 77.395954
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.392375
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.388873
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.385467
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.382132
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.378886
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.375708
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.372612
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.369578
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.366622
#          Iterations: 6
#          Function evaluations: 30
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 77.363724
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.360899
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.358128
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.355425
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.352774
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.350186
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.347646
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.345166
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.342731
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.340352
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.338016
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.335733
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.333490
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.331296
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.329141
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.327032
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.324959
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.322931
#          Iterations: 6
#          Function evaluations: 30
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 77.320936
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.318983
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.317062
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.315181
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.313329
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.311516
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.309731
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.307982
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.306260
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.304572
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.302909
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.301279
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.299673
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.298098
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.296545
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.295022
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.293521
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.292048
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.290596
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.289170
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.287764
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.286384
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 77.285022
#          Iterations: 6
#          Function evaluations: 60
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 77.283684
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.282365
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.281069
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.279790
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.278533
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.277292
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.276073
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.274869
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.273686
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.272517
#          Iterations: 7
#          Function evaluations: 33
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 77.271368
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.270233
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.269117
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.268015
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.266930
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.265859
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.264804
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.263763
#          Iterations: 7
#          Function evaluations: 30
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 77.262737
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77.261724
#          Iterations: 6
#          Function evaluations: 27
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 77.260727
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 77